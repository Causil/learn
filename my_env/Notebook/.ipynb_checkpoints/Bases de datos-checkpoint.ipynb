# %% [markdown]
# <h1> SQL</h1>
#
# <a href='https://www.w3schools.com/sql/sql_intro.asp' > Documentación </a>
# <h4>What Can SQL do?</h4>
#
#     SQL can execute queries against a database
#     SQL can retrieve data from a database
#     SQL can insert records in a database
#     SQL can update records in a database
#     SQL can delete records from a database
#     SQL can create new databases
#     SQL can create new tables in a database
#     SQL can create stored procedures in a database
#     SQL can create views in a database
#     SQL can set permissions on tables, procedures, and views

# %% [markdown]
# <h1>PostgreSQL</h1>
#
# <a href='https://www.postgresql.org/docs/current/' >Documentación<a>
#
# <a href=''>
#
# <h4>Qué es postgresql?</h4>
# es un sistema de bases de datos de objetos relacionales (ORDBMS-object-relational database management system )
# desarrollada en el departamento de ciencas de la computanción en la universidad de Berkeley en California. POSTGRES es pionera de muchos conceptos que solo fueron displonibles mas tarde en algunos sistemas de base de datos comerciales.
#
# Postgresql es de codigo-abierto decendiente de este códifo orininal de Berkeley. Esta soportada en gran parte por el estandar de SQL y ofrece muchas caracteristicas modernas:
#
#     Consultas complejas.
#     llaves foraneas.
#     Disipadores.
#     Vistas de actualizables.
#     Integridad transaccional.
#     Control de concurrencia de múltiples versiones.
#
# Además, PostgreSQL puede ser extendida por el usuario de muchas maneras, por ejemplo agregando nuevos:
#
#     Tipos de datos.
#     Funciones.
#     Operadores.
#     Funciones agregadas.
#     Métodos indexados.
#     Lenguajes de procedimiento.
#
# y porque la licencia es libre, PostgreSQL puede ser, módificada, y distribuida por cualquer persona de forma gratuita para cualquier proposito, puede ser privada, comercial, o académico.
#
#
#
# Concepto de lenguajes de datos:
#
# El motor de base de datos mas popular del mundo.
#
# Lenguaje:  Lo que permite agregar información o realizar querys en una base de datos. Ejemplo SQL
#
# Motor: Permite estructurar la información dentro de un servidor. Ejemplo: postgreSQL, MySQL.
#
# Servidor: Un equipo el cual tiene una memoría y una ram para que funcione el motor de la base de datos.
#
# Open Source: Un equipo el cual tiene una memoría y una ram para que funcione el motor de base de datos.
#
# Objeto Relacional: Se programa teniendo como referencia también la programación orientada a objetos por temas como la herencia.
#
# PostGIS: plugin para recibir información de sistemas información geográfica.
#
# PL/PgSQL: Lenguaje backend interno del motor de base de datos.
#
# Cumple ACID: Cantidad de reglas que deben cumplir las bases de datos para garantizar buenas practicas.
#
# A: Atomicity: Puedo separar las funciones programadas para la base de datos en pequeñas tareas y desarrolladas como un todo de modo que cuando ejecutas todas las tareas pero si alguna de ellas falla se hace un rolback, o se deshacen los cambios de cada una de las que se habian pasado.
#
# C: Consistency: Todo lo que se desarrollo entorno al objeto relacional en el que tu puedes tener dos tablas que están relacionadas con llaves primarias, llaves foráneas.
#
# I: Isolation: (Aislamiento) Puedes tener varias tareas ejecutandose al mismo tiempo
#     dentro de la base de datos, puedes tener consultas y al mismo tiempo tener modificaciones desde una tabla diferente,  puedes tener roles diferentes accediendo a la base de datos. Es decir puedes tener aisladas las funciones que se ejecutan dentro de la base de datos.
#
#
# D: Durability: (Durabilidad) Puedes tener la seguridad de que la información no se va a perder. Digamos que el servidor donde estaba corriendo, se apagó durante una inserción, esa información no se va a perder por que postgreSQL uso un sustema en el guarda la información en una bitácora y luego hace el cambio efectivo en la base de datos.
#
# <img src='https://static.platzi.com/media/user_upload/myimag-2df74ee2-eb6d-44ff-902f-c1aeae8f0b70.jpg'>

# %% [markdown]
# Instalación en ubuntu de <a href='https://www.postgresql.org/download/linux/ubuntu/'>postgresql<a> y <a href='https://www.pgadmin.org/download/pgadmin-4-apt/'>pgAdmin4<a>:
#
#
# Para iniciar postgresql desde la términal <h5>sudo -u postgres psql</h5>
#
# Resumen:
#
#     ENTRAR A LA CONSOLA DE POSTGRES
#     psql -U postgres -W
#     sudo -u postgres psql
#
#     VER LOS COMANDOS \ DE POSTGRES
#     \?
#
#     LISTAR TODAS LAS BASES DE DATOS
#     \l
#
#     VER LAS TABLAS DE UNA BASE DE DATOS
#     \dt
#
#     CAMBIAR A OTRA BD
#     \c nombre_BD
#
#     DESCRIBIR UNA TABLA
#     \d nombre_tabla
#
#     VER TODOS LOS COMANDOS SQL
#     \h
#
#     VER COMO SE EJECTUA UN COMANDO SQL
#     \h nombre_de_la_funcion
#
#     CANCELAR TODO LO QUE HAY EN PANTALLA
#     Ctrl + C
#
#     VER LA VERSION DE POSTGRES INSTALADA, IMPORTANTE PONER EL ';'
#     SELECT version();
#
#     VOLVER A EJECUTAR LA FUNCION REALIADA ANTERIORMENTE
#     \g
#
#     INICIALIZAR EL CONTADOR DE TIEMPO PARA QUE LA CONSOLA TE DIGA EN CADA EJECUCION ¿CUANTO DEMORO EN EJECUTAR ESA FUNCION?
#     \timing
#
#     LIMPIAR PANTALLA DE LA CONSOLA PSQL
#     Ctrl + L

# %% [markdown]
# <h1> Archivos de configuración </h1>
#
# postgresql.conf
#
# pg_hba.conf
#
# pg_ident.conf
#
#
# Desde el editor de pgadmin podemos ejecutar el siguiente comando para que nos muestre la ruta donde estan los archivos
#
# Para que postgresql tome los cambios que hagamos en estos archivos tenemos que reiniciar la base de datos, desde
#
# Ayudas: https://e-mc2.net/blog/configuracion-basica-de-postgresql/
#
# https://platzi.com/blog/administracion-usuarios-servidores-linux/
#
# SHOW config_file;
#
# postgresql.conf:
#
# Registro de querys mas lentas, configurar nuestra base de datos en modo replica,... conexiones y autenticaciones a la base de datos, puedes modificar desde que direcciones escucha para permitirle o no a un servidor externo conectarse a tu base de datos, cambiar el puerto, cantidad máxima de conexiones,  podemos configurar
#
# Toda persona que maneja base de datos postgresql debe leerse el archivo postgresql.conf, ya que nos dara idea de cuanta modificación podemos modíficar, por ejemplo no hay memoría en servidor, la cantidad de procesos se ha acabado(un proceso es una tarea que se esta ejecutando en la base de datos), la cantidad de roles esta excediendo el límite, que la cpu esta al 100%, lo que veamos que no tenga que ver con base de datos pero que no esta permitiendo ejecutar mis funciones o tus consultas bien, tendras que venir a revisar por que muchas veces tiene que ver con este archivo. También puedes encontrar toda la configuración actual de la base de datos,
#
# pg_hba.conf:
# Muestra los roles y los tipos de acceso que tienen a tu base de datos. La documentación explica los metodos las fuentes, esta a configuración que hicimos con pgadmin,
#
# pg_idenf.conf:
# Este fichero se utiliza para definir la información necesaria en el caso que utilicemos un acceso del tipo ident en pg_hba.conf .

# %% [markdown]
# Comandos de navegación y consulta de información
#
#     \c Saltar entre bases de datos
#
#     \l Listar base de datos disponibles
#
#     \dt Listar las tablas de la base de datos
#
#     \d <nombre_tabla> Describir una tabla
#
#     \dn Listar los esquemas de la base de datos actual
#
#     \df Listar las funciones disponibles de la base de datos actual
#
#     \dv Listar las vistas de la base de datos actual
#
#     \du Listar los usuarios y sus roles de la base de datos actual
#
# Comandos de inspección y ejecución
#
#     \g Volver a ejecutar el comando ejecutando justo antes
#
#     \s Ver el historial de comandos ejecutados
#
#     \s <nombre_archivo> Si se quiere guardar la lista de comandos ejecutados en un archivo de texto plano
#
#     \i <nombre_archivo> Ejecutar los comandos desde un archivo
#
#     \e Permite abrir un editor de texto plano, escribir comandos y ejecutar en lote. \e abre el editor de texto, escribir allí todos los comandos, luego guardar los cambios y cerrar, al cerrar se ejecutarán todos los comandos guardados.
#
#     \ef Equivalente al comando anterior pero permite editar también funciones en PostgreSQL
#
# Comandos para debug y optimización
#
#     \timing Activar / Desactivar el contador de tiempo por consulta
#
# Comandos para cerrar la consola
#
#     \q Cerrar la consola

# %% [markdown]
# Practica:
#
# Crear una base de datos: CREATE DATABASE transporte;
# Crear la tabla tren: CREATE TABLE tren(id     serial NOT NULL,
#                                        modelo character varying,
#                                        capacidad integer,
#                                        CONSTRAINT tren_pkey
#                                        PRIMARY KEY (id)
#                                       );
#
# La columna id será un número autoincremental (cada vez que se inserta un registro se aumenta en uno), modelo se refiere a una referencia al tren, capacidad sería la cantidad de pasajeros que puede transportar y al final agregamos la llave primaria que será id.
#
# Vemos la tabla usando el comando: \d tren.
#
# Podemos ver en los campos de la tabla en la consola, la columna 'Default', clasifica a id como nextval('tren_id_seq'::regclass)
#
# si ejecutamos \d tren_id_seq :
#
#     Podemos notar que es tipo entero, comienza en 1, el mínimo valor que toma es 1, el máximo valor que toma
#     es 2147483647, tiene  un incremento de 1.
#
# Investigar más sobre \d tren_id_seq.
#
# Ingresemos un dato en nuestra tabla con el siguiente comando:
#         INSERT INTO tren
#                     (modelo, capacidad)
#                     VALUES
#                     ('Volvo 1', 100);
#
# Consultemos los datos en la tabla: SELECT * FROM tren;
#
# Vamos a modíficar el valor, establecer el tren con id uno que sea modelo Honda 0726. Para ello ejecutamos la consulta tipo actualización:
#
# UPDATE tren SET modelo = 'Honda 0726' WHERE id =1;
#
# utilicemos el comando SELECT * FROM tree, para verificar que el elemento ha cambiado.
#
# Ahora borramos la fila con el comando:
#
# DELETE FROM tren WHERE id = 1;
#
# Ahora verifiquemos que se ha eliminado la fila.
#
# Para medir el tiempo en que se demora una consulta utilizamos el comando :
#
#       \timing
#
# Probemos cómo funciona encriptando un texto cualquiera usando el algoritmo md5:
#
# SELECT MD5('Vamos a encriptar un texto como el que lees');

# %% [markdown]
# <h2> Presentación del proyecto </h2>
#
# Imagina un sistema de transporte masivo, una estación, un tren, la cantidad de pasajeros, modela el sistema.
#
# componentes: pasajeros, trenes, trayectos, estación,
#
# Postgres es la solución perfecta por que es una entidad modelo relacional, Pasajero, trayecto, estación, tren y viaje.
#
# Los elementos más importantes del sistema son pasajero, estación y tren.
#
#
# Tipos de Datos en postgresql:
#
# <a href='https://www.todopostgresql.com/postgresql-data-types-los-tipos-de-datos-mas-utilizados/'>Documentación </a>
#
#
#     Númericos:
#
#     Monetarios:
#
#     Texto:
#
#     Binarios:
#
#     Fecha/hora:
#
#     Boolean:
#
# <a href='https://www.ibiblio.org/pub/linux/docs/LuCaS/Tutoriales/NOTAS-CURSO-BBDD/notas-curso-BD/node134.html'>Formatos propios de postgresql </a>:
#
#
#
#     Geométricos: Permiten calcular distancias y áreas
#
#     Direcciones de red: Almacenan ip, permiten hacer calculos de mascaras de red,
#
#     Texto tipo bit(Para hacer calculos en otros sistemas sexagesimal o binario)
#
#     xml,JSON(guardar formatos de Api),
#
#     Arreglos(Vectores y matrices).
#
# Para crear las relaciones entre las tables debemos saber, estandar entidad relación
#
# <a href='https://app.diagrams.net/'> Draw.io </a> y  <a href='https://www.lucidchart.com/pages/es/que-es-un-diagrama-entidad-relacion'>diagrama entidad-relación</a>
#
# Un diagrama entidad-relación, también conocido como modelo entidad relación o ERD, es un tipo de diagrama de flujo que ilustra cómo las "entidades", como personas, objetos o conceptos, se relacionan entre sí dentro de un sistema. Los diagramas ER se usan a menudo para diseñar o depurar bases de datos relacionales en los campos de ingeniería de software, sistemas de información empresarial, educación e investigación. También conocidos como los ERD o modelos ER, emplean un conjunto definido de símbolos, tales como rectángulos, diamantes, óvalos y líneas de conexión para representar la interconexión de entidades, relaciones y sus atributos. Son un reflejo de la estructura gramatical y emplean entidades como sustantivos y relaciones como verbos.
#
# Una estación puede tener muchos trayectos.
#
# un Tren puede tener muchos trayectos
#
#
# Plantear esta situación de tablas es fundamental ya que nos permite relacionar las tablas de datos.
#
#
# Creando tablas:
#
#
#     CREATE: inicializar la estructura de la base de la tabla.
#
#     ALTER: para agregar columnas eliminar columnas, cambiar indices, agregar llaves primarias, e incluso agregar roles como propietarios de la tabla,
#
#     DROP: nos permite borrar la tabla con toda la información
#
#
# Cuando se tenga mucha información en una tabla para encontrar el dato que buscamos, se tiene que recorrer cada espacio de memoría de la base de datos, imaginemos que nuestra tabla viajes
#
# Particiones:
#
#     Separación física de datos: guardar varias partes de la misma tabla en diferentes espacios de disco.
#
#     Estructura lógica: funciona el mismo select de simepre,
#
#
# CREATE TABLE pasajeros(
# 	id serial,
# 	nombre character varying(100),
# 	direccion_residencia character varying,
# 	fecha_nacimiento date,
# 	CONSTRAINT pasajero_pkey PRIMARY KEY (id)
# )
# CREATE TABLE trenes(
# 	id serial,
# 	modelo character varying(30),
# 	capacidad integer,
# 	CONSTRAINT tren_pkey PRIMARY KEY (id)
# )
# CREATE TABLE estaciones(
# 	id serial,
# 	nombre character varying(30),
# 	direccion character varying(100),
# 	CONSTRAINT estacion_pkey PRIMARY KEY (id)
# )
# CREATE TABLE trayectos(
# 	id serial,
# 	id_tren integer,
# 	id_estacion integer,
# 	CONSTRAINT trayecto_pkey PRIMARY KEY (id),
# 	FOREIGN KEY (id_tren) REFERENCES estacion(id),
# 	FOREIGN KEY (id_estacion) REFERENCES tren(id)
# )
# CREATE TABLE viajes(
# 	id serial,
# 	id_pasajero integer,
# 	id_trayecto integer,
# 	inicio date,
# 	fin date,
# 	CONSTRAINT viaje_pkey PRIMARY KEY (id),
# 	FOREIGN KEY (id_pasajero) REFERENCES pasajero (id),
# 	FOREIGN KEY (id_trayecto) REFERENCES trayecto (id)
# )
#
# --------------------------------------------------------------------------------------------------------
# CREATE TABLE pasajeros (
# 	id                   serial,
# 	nombre               character varying(100),
# 	direccion_residencia character varying,
# 	fecha_nacimiento     date,
# 	CONSTRAINT pasajeros_pkey PRIMARY KEY(id)
# );
# CREATE TABLE trenes (
# 	id        serial,
# 	nombre    character varying(30),
# 	capacidad integer,
# 	CONSTRAINT trenes_pkey PRIMARY KEY(id)
# );
# CREATE TABLE estaciones(
# 	id        serial,
# 	nombre    character varying(30),
# 	direccion character varying(100),
# 	CONSTRAINT estaciones_pkey PRIMARY KEY(id)
# );
# CREATE TABLE trayectos(
# 	id          serial,
# 	id_tren     integer,
# 	id_estacion integer,
# 	CONSTRAINT trayecto_pkey PRIMARY KEY(id),
# 	FOREIGN KEY (id_tren) REFERENCES estaciones(id),
# 	FOREIGN KEY (id_estacion) REFERENCES trenes(id)
# );
# CREATE TABLE viajes(
# 	id          serial,
# 	id_pasajero integer,
# 	id_trayecto integer,
# 	inicio      date,
# 	fin         date,
# 	CONSTRAINT viaje_pkey PRIMARY KEY(id),
# 	FOREIGN KEY (id_pasajero) REFERENCES pasajeros (id),
# 	FOREIGN KEY (id_trayecto) REFERENCES trayectos (id)
# );
#
#
# Ahora vamos a insertar un elemento en nuestra base de datos:
#
# INSERT INTO public.pasajeros(
# 	nombre, direccion_residencia, fecha_nacimiento)
# 	VALUES ('Nombre', 'carr 10 calle 24-53', '05/05/05');
#
# SELECT current_date;
#
# para saber el formato de la fecha es año-mes-dia
#
# creando particiones
#
# CREATE TABLE public.bitacora_viajes
# (
#
#     id serial,
#     id_viaje integer,
#     fecha date
# ) PARTITION BY RANGE (fecha);
#
# ALTER TABLE IF EXISTS public.bitacora_viajes
#     OWNER to postgres;
#
#  INSERT INTO public.bitacora_viajes(
# 	id_viaje, fecha)
# 	VALUES
# 	('1', '2022-06-21');
#
#
#
# Creando la partición
#
# CREATE TABLE  bitacora_viajes202201 PARTITION of bitacora_viajes
# FOR VALUES FROM ('2010-01-01') TO ('2022-12-31');
#
# <img src='https://static.platzi.com/media/user_upload/Captura2-28c2695b-6973-429f-a41e-8998a49ebd2e.jpg' >
#
# Cuando se crean las particiones, podemos crear cuantas particiones queramos
#
# No es posible crear llaves primarias en tablas particionadas, ya que la información esta toda dividida, no te preocupes ya que el uso de las tablas particionadas es para cuando queramos guardar información en masa, como bitacoras, y esta información deben hacer referecnias a las tablas que ya tienen las llaves primarias, por eso no se hace uso de llaves primarias.
#
# Roles: los roles en la base de datos tienen la cualidad de ser creados o eliminados, tienen una caracteristica especial,
#
#         Crear y eliminar otros roles.
#         Asignar atributos pueden hacer login o no, pueden eliminar tablas,
#         Agrupar con otros roles, pueden ser agrupados bajo un conjunto global de permisos.
#         Roles predeterminados, es peligroso siempre utilizar el rol predeterminado de postgres ya que tiene poder absoluto sobre la base de datos, y si cometemos un error podemos dañar todo lo que hemos hecho, lo ideal es crear un usuario con lo sniveles de seguridad indicados para nuestras tablas y nuestra base de datos y continuar trabajando con él. Lo vamos a crear usando la consola y usando pgadmi,
#
#
# los roles son independientes a las bases de datos, entonces no necesitamos saltar de una base de datos para crear un rol o no.
#
# para ingresar desde consola solo ejecutamos el siguiente comando:
#
#
# psql -h <host> -d <basededatos> -U <usuario> -p <port>
#
# psql -h 127.0.0.1 -d MIBDOFI  -U usuario_consulta -p 5432
#
#
# psql -h 127.0.0.1 -U postgres -p 5432
#
#
# consulta para crear un rol:
#         CREATE ROL
#
# estudiemos el comando es decir, desde consola ejecutamos
#
#        \h CREATE ROL
#
#
# postgres=# \h CREATE ROL
# Command:     CREATE ROLE
# Description: define a new database role
# Syntax:
# CREATE ROLE name [ [ WITH ] option [ ... ] ]
#
# where option can be:
#
#       SUPERUSER  | NOSUPERUSER
#     | CREATEDB   | NOCREATEDB
#     | CREATEROLE | NOCREATEROLE
#     | INHERIT    | NOINHERIT
#     | LOGIN      | NOLOGIN
#     | REPLICATION | NOREPLICATION
#     | BYPASSRLS   | NOBYPASSRLS
#     | CONNECTION LIMIT connlimit
#     | [ ENCRYPTED ] PASSWORD 'password' | PASSWORD NULL
#     | VALID UNTIL 'timestamp'
#     | IN ROLE role_name [, ...]
#     | IN GROUP role_name [, ...]
#     | ROLE role_name [, ...]
#     | ADMIN role_name [, ...]
#     | USER role_name [, ...]
#     | SYSID uid
#
# URL: https://www.postgresql.org/docs/14/sql-createrole.html
#
# postgres=#
#
#
# Vamos a crear un rol que pueda hacer login y le asignamos una contraseña, es decir el rol de postgres para crear  tablas y el otro rol para hacer consultas,
#
#     CREATE ROLE usuario_consulta;
#
#
#     ALTER ROLE usuario_consulta WITH PASSWORD 'etc123';
#
# para ver los usuarios que estan creados ejecutamos el comando \dg
#
#     DROP ROLE usuario_consulta;
#
#
#
# Creando llaves foraneas: Se refiere a las relaciones que existen entre las tablas
#
# Estrutura de llaves foraneas
#
#         Tabla de origen
#         Tabla destino
#         Acciones
