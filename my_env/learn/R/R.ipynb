# %% [markdown]
# <h1> Cómo instalar R  </h1>
#
# Link para descargar Cran
#
# <a href='https://www.icesi.edu.co/CRAN'> Repositorio principal </a>
#
# Link para descargar la suite de R
# <a href="">R studio</a>
#
# <p>
# javier@javier-Lenovo-G40-80:~$ sudo apt --fix-broken install r-base-core
# Leyendo lista de paquetes... Hecho
# Creando árbol de dependencias... Hecho
# Leyendo la información de estado... Hecho
# Tal vez quiera ejecutar «apt --fix-broken install» para corregirlo.
# Los siguientes paquetes tienen dependencias incumplidas:
#  teams : Depende: libgdk-pixbuf2.0-0 (>= 2.22.0) pero no va a instalarse
# E: Dependencias incumplidas. Intente «apt --fix-broken install» sin paquetes (o especifique una solución).
# </p>
#
# <a  style="color:red" href="https://www.enfaseterminal.com/2019/01/resolver-dependencias-al-instalar-un.html">
# javier@javier-Lenovo-G40-80:~$ sudo apt --fix-broken install r-base-core
# </a>
#
# Se crea un problema de dependencias
#
#
# Packages para crear un dashboar interactivo
#
# ¿Qué hace cada paquete?
#
# Para colores jcolors ggs
#
# Para realizar correlaciones corrr corrplot
#
# Presentaciones xaringa
#
# shiny bslib thematic flexdashboard rmarkdown tidyverse janitor DT plotly jcolors ggs corrr corrplot visdat reticule  shinycssloaders shinyWidgets xaringa rticles
#
# R shiny gallery
#
# No tildes, no ñ y espacios en blancos
#
# rproject-udea-netfly.app
#
# https://webdesign.tutsplus.com/es/articles/quick-and-easy-documentation-using-markdown--webdesign-8163
#
#
# https://estadistica-dma.ulpgc.es/cursoR4ULPGC/20-Rmarkdown.html

# %%
import pandas as pd

# %%
import numpy as pd

# %% [markdown]
# <ol>
# <li>
#     Xaringa: para crear diapositivas
# </li>
# <li>
#     Plotly: para gráficar
# </li>
# <li>
# </li>
# <ol>

# %%
import requests
#import pandas as pd
import numpy as np
res = requests.get('https://www.datos.gov.co/resource/w8hf-jz4a.json')
print(res.json())
# Out:
# [{'solicitud': 'NC2016/0000004', 'a_o_concesi_n': '2018', 'naturaleza': 'Patente PCT', 'sector': 'Otros sectores', 'titulo': 'MÉTODO PARA LA CARACTERIZACIÓN DE UNA FORMACIÓN SUBTERRÁNEA QUE INCLUYE LA MEDICIÓN DE UNA RESPUESTA DE PRESIÓN POROELÁSTICA A TRAVÉS DE UN SENSOR DE PRESIÓN', 'fecha_de_concesion': '2018-09-19T00:00:00.000', 'pais': 'US', 'solicitante': 'CONOCOPHILLIPS COMPANY (US)', 'inventor': 'ADOLFO ANTONIO RODRIGUEZ; HORACIO FLOREZ; NICOLAS PATRICK ROUSSEL', 'clasificacion': 'E21B 47/00; E21B 47/06; G01V 1/40', 'residente': 'No residente', 'tr_mite': 'Patente de Invención', 'pa_s_nom': 'Estados Unidos de América', 'v_a_presntac': 'PCT'}, {'solicitud': 'NC2016/0000013', 'a_o_concesi_n': '2019', 'naturaleza': 'Patente de Invención Nacional', 'sector': 'Química', 'titulo': 'PROCESO PARA OBTENER CARAMELOS DE BASE PROTEICA DE CARNE DE PESCADO, RES, CERDO O POLLO Y CARAMELO DE BASE PROTEICA ASÍ OBTENIDO', 'fecha_de_concesion': '17/09/2019', 'pais': 'CO', 'region': 'MAGDALENA', 'ciudad': 'SANTA MARTA', 'solicitante': 'UNIVERSIDAD DEL MAGDALENA (CO)', 'inventor': 'ALVARO ESPELETA MAYA; ARMANDO LACERA RUA; EDUARDO CABRERA DURÁN; OMAR CARREÑO MONTOYA; RUBY CORVACHO NARVÁE; VICTOR MÁRQUEZ ZALDUA', 'clasificacion': 'A23J 3/00; A23J 3/04', 'residente': 'Residente', 'tr_mite': 'Patente de Invención', 'pa_s_nom': 'Colombia', 'v_a_presntac': 'Nacional'}, {'solicitud': 'NC2016/0000015', 'a_o_concesi_n': '2018', 'naturaleza': 'Patente PCT', 'sector': 'Química', 'titulo': 'COMPOSICIÓN PARA TRATAMIENTO DE FORMACIONES SUBTERRÁNEAS QUE COMPRENDE ÁCIDO EMULSIONADO Y SULFOBETAÍNA Y MÉTODO PARA TRATAR UNA FORMACIÓN SUBTERRÁNEA', 'fecha_de_concesion': '18/09/2018', 'pais': 'NL', 'solicitante': 'SCHLUMBERGER TECHNOLOGY B.V. (NL); PRAD RESEARCH AND DEVELOPMENT LIMITED (VG); SCHLUMBERGER CANADA LIMITED (CA); SCHLUMBERGER HOLDINGS LIMITED (VG); SCHLUMBERGER TECHNOLOGY CORPORATION (US); SERVICES PETROLIERS SCHLUMBERGER (FR)', 'inventor': 'ARTHUR WILLIAM MILNE; EMILIO MIQUILENA; SYED A. ALI', 'clasificacion': 'C09K 8/02; C09K 8/72; E21B 43/22', 'residente': 'No residente', 'tr_mite': 'Patente de Invención', 'pa_s_nom': 'Países Bajos', 'v_a_presntac': 'PCT'}, {'solicitud': 'NC2016/0000018', 'a_o_concesi_n': '2018', 'naturaleza': 'Patente PCT', 'sector': 'Química', 'titulo': 'ANTICUERPOS BIESPECÍFICOS ANTI-CD3/CD20', 'fecha_de_concesion': '13/08/2018', 'pais': 'US', 'solicitante': 'GENENTECH INC. (US)', 'inventor': 'ALLEN J. JR. EBENS; LIPING L. SUN ; MARK S. DENNIS; MARY A. MATHIEU ; ROBERT F KELLEY; TEEMU T. JUNTTILA; XIAOCHENG CHEN', 'clasificacion': 'C07K 16/28; C07K 16/30; C07K 16/32; A61K 39/395; A61P 35/00; A61P 37/00', 'residente': 'No residente', 'tr_mite': 'Patente de Invención', 'pa_s_nom': 'Estados Unidos de América', 'v_a_presntac': 'PCT'}, {'solicitud': 'NC2016/0000020', 'a_o_concesi_n': '2019', 'naturaleza': 'Patente PCT', 'sector': 'Química', 'titulo': 'UNA COMPOSICION QUE COMPRENDE DICAMBA Y UN AGENTE DE CONTROL DE DERIVA QUE COMPRENDE UN ALCOHOL GRASO', 'fecha_de_concesion': '08/04/2019', 'pais': 'DE', 'region': 'RHEINLAND-PFALZ', 'ciudad': 'LUDWIGSHAFEN AM RHEIN', 'solicitante': 'BASF SE (DE)', 'inventor': 'MAARTEN STAAL; TERRANCE CANNAN', 'clasificacion': 'A01N 25/00; A01N 37/40; A01N 25/30', 'residente': 'No residente', 'tr_mite': 'Patente de Invención', 'pa_s_nom': 'Alemania', 'v_a_presntac': 'PCT'}, {'solicitud': 'NC2016/0000028', 'a_o_concesi_n': '2018', 'naturaleza': 'Patente PCT', 'sector': 'Química', 'titulo': 'LIPIDO QUE COMPRENDE ACIDOS GRASOS POLIINSATURADOS DE CADENA LARGA', 'fecha_de_concesion': '07/11/2018', 'pais': 'AU', 'solicitante': 'COMMONWEALTH SCIENTIFIC AND INDUSTRIAL RESEARCH ORGANISATION (AU); GRAINS RESEARCH AND DEVELOPMENT CORPORATION (AU); NUSEED PTY LTD (AU)', 'inventor': 'JAMES ROBERTSON PETRIE; JASON TIMOTHY MCALLISTER; MALCOLM DAVID DEVINE; PUSHKAR SHRESTHA; ROBERT CHARLES DE FEYTER; SURINDER PAL SINGH', 'clasificacion': 'A01H 5/00; C11B 1/10; C12N 15/52; C07H 21/04; C12N 15/82; C12N 15/79', 'resid ...

# %%
res.headers
res[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/javier/Documentos/manual/manualUsuario/my_env/learn/R/R.ipynb Celda 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/javier/Documentos/manual/manualUsuario/my_env/learn/R/R.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> res.headers
#       <a href='vscode-notebook-cell:/home/javier/Documentos/manual/manualUsuario/my_env/learn/R/R.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> res[0]
#
# NameError: name 'res' is not defined
